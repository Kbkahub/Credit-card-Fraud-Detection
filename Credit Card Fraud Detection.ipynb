# %%
import pandas as pd

# %%
pd.read_csv("creditcard.csv")
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data = pd.read_csv("creditcard.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.options.display.max_columns = None

# %%
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data.tail(5)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
284807
# Out:
# 284807

# %%
data.shape
# Out:
# (284807, 31)

# %%
print("Number of columns: {}".format(data.shape[1]))
# Out:
# Number of columns: 31

# %%
print("Number of rows: {}".format(data.shape[0]))
# Out:
# Number of rows: 284807

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
data['Amount'] = sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data = data.drop(['Time'], axis = 1)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
data.shape
# Out:
# (284807, 30)

# %%
data.duplicated().any()
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
class_counts = data['Class'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(class_counts.index, class_counts.values)
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Count of Each Class')
plt.show()

# %%
X = data.drop('Class', axis = 1)
Y = data['Class']

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score

# %%
classifier = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree Classifier' : DecisionTreeClassifier(),
    'Random Forest Classifier' : RandomForestClassifier()
}

for name, clf in classifier.items():
    print(f'\n=========={name}=============')
    clf.fit(X_train,Y_train)
    y_pred = clf.predict(X_test)
    print(f"\n Accuracy:{accuracy_score(Y_test, y_pred)}")
    print(f"\n Recall:{recall_score(Y_test, y_pred)}")
    print(f"\n Precision:{precision_score(Y_test, y_pred)}")
    print(f"\n F1 Score:{f1_score(Y_test, y_pred)}")
# Out:
# ==========Logistic Regression=============
#
#  Accuracy:0.9992563437505668
#
#  Recall:0.6263736263736264
#
#  Precision:0.890625
#
#  F1 Score:0.7354838709677419
#
# ==========Decision Tree Classifier=============
#
#  Accuracy:0.9990024123483213
#
#  Recall:0.7252747252747253
#
#  Precision:0.6875
#
#  F1 Score:0.7058823529411765
#
# ==========Random Forest Classifier=============
#
#  Accuracy:0.9994377233235993
#
#  Recall:0.7472527472527473
#
#  Precision:0.8947368421052632
#
#  F1 Score:0.8143712574850299

# %%
#undersampling

# %%
Normal = data[data['Class']==0]
Fraud = data[data['Class']==1]

# %%
Normal.shape
# Out:
# (275190, 30)

# %%
Fraud.shape
# Out:
# (473, 30)

# %%
Normal_sample = Normal.sample(n=473)

# %%
Normal_sample.shape
# Out:
# (473, 30)

# %%
new_data = pd.concat([Normal_sample,Fraud],ignore_index = True)

# %%
new_data
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# 0    2.177158 -1.590418 -1.042034 -1.737336 -1.023209  0.053239 -1.231631
# 1   -0.452137 -1.391375  0.979204  0.885136 -4.097142  2.343622  1.961438
# 2   -2.367054  2.299903  0.907886  1.878088 -1.722806  1.142706 -2.933602
# 3    1.060710 -0.479958  1.457818  0.082964 -1.472982 -0.396238 -0.867734
# 4   -0.336294 -0.104040  1.674249 -0.768755 -1.003159 -0.129062  0.128088
# ..        ...       ...       ...       ...       ...       ...       ...
# 941 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 942  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 943 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 944 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 945  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
#            V8        V9       V10       V11       V12       V13       V14  \
# ...

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  2.177158 -1.590418 -1.042034 -1.737336 -1.023209  0.053239 -1.231631
# 1 -0.452137 -1.391375  0.979204  0.885136 -4.097142  2.343622  1.961438
# 2 -2.367054  2.299903  0.907886  1.878088 -1.722806  1.142706 -2.933602
# 3  1.060710 -0.479958  1.457818  0.082964 -1.472982 -0.396238 -0.867734
# 4 -0.336294 -0.104040  1.674249 -0.768755 -1.003159 -0.129062  0.128088
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.013090 -1.395929  1.687788  0.326234 -0.072383  0.820564 -0.401849
# 1 -0.268335  0.528607  0.318734 -2.125690 -1.585506 -1.894695 -0.857436
# 2 -4.193775 -0.478264 -1.539593 -1.755056  0.164437 -1.966006  1.263401
# 3  0.133317  0.846972 -0.316184  0.376173  0.473729  0.258101 -0.203406
# 4  0.032740 -1.088126  0.212242 -1.350784 -1.030571 -0.241270 -0.126476
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
new_data.shape
# Out:
# (946, 30)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
X = new_data.drop('Class', axis = 1)
Y = new_data['Class']

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  2.177158 -1.590418 -1.042034 -1.737336 -1.023209  0.053239 -1.231631
# 1 -0.452137 -1.391375  0.979204  0.885136 -4.097142  2.343622  1.961438
# 2 -2.367054  2.299903  0.907886  1.878088 -1.722806  1.142706 -2.933602
# 3  1.060710 -0.479958  1.457818  0.082964 -1.472982 -0.396238 -0.867734
# 4 -0.336294 -0.104040  1.674249 -0.768755 -1.003159 -0.129062  0.128088
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0 -0.013090 -1.395929  1.687788  0.326234 -0.072383  0.820564 -0.401849
# 1 -0.268335  0.528607  0.318734 -2.125690 -1.585506 -1.894695 -0.857436
# 2 -4.193775 -0.478264 -1.539593 -1.755056  0.164437 -1.966006  1.263401
# 3  0.133317  0.846972 -0.316184  0.376173  0.473729  0.258101 -0.203406
# 4  0.032740 -1.088126  0.212242 -1.350784 -1.030571 -0.241270 -0.126476
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
classifier = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree Classifier' : DecisionTreeClassifier(),
    'Random Forest Classifier' : RandomForestClassifier()
}

for name, clf in classifier.items():
    print(f'\n=========={name}=============')
    clf.fit(X_train,Y_train)
    y_pred = clf.predict(X_test)
    print(f"\n Accuracy:{accuracy_score(Y_test, y_pred)}")
    print(f"\n Recall:{recall_score(Y_test, y_pred)}")
    print(f"\n Precision:{precision_score(Y_test, y_pred)}")
    print(f"\n F1 Score:{f1_score(Y_test, y_pred)}")
# Out:
# ==========Logistic Regression=============
#
#  Accuracy:0.9421052631578948
#
#  Recall:0.9117647058823529
#
#  Precision:0.9789473684210527
#
#  F1 Score:0.9441624365482234
#
# ==========Decision Tree Classifier=============
#
#  Accuracy:0.8842105263157894
#
#  Recall:0.8823529411764706
#
#  Precision:0.9
#
#  F1 Score:0.8910891089108911
#
# ==========Random Forest Classifier=============
#
#  Accuracy:0.9473684210526315
#
#  Recall:0.9117647058823529
#
#  Precision:0.9893617021276596
#
#  F1 Score:0.9489795918367347

# %%
#Oversampling using SMOTE

# %%
X = data.drop('Class', axis = 1)
Y = data['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
Y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res, Y_res = SMOTE().fit_resample(X,Y)

# %%
Y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_res, Y_res, test_size = 0.2, random_state = 42)

# %%
classifier = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree Classifier' : DecisionTreeClassifier(),
    'Random Forest Classifier' : RandomForestClassifier()
}

for name, clf in classifier.items():
    print(f'\n=========={name}=============')
    clf.fit(X_train,Y_train)
    y_pred = clf.predict(X_test)
    print(f"\n Accuracy:{accuracy_score(Y_test, y_pred)}")
    print(f"\n Recall:{recall_score(Y_test, y_pred)}")
    print(f"\n Precision:{precision_score(Y_test, y_pred)}")
    print(f"\n F1 Score:{f1_score(Y_test, y_pred)}")
# Out:
# ==========Logistic Regression=============
#
#  Accuracy:0.9448108579526873
#
#  Recall:0.9152046252022616
#
#  Precision:0.9727342995169083
#
#  F1 Score:0.9430929341564172
#
# ==========Decision Tree Classifier=============
#
#  Accuracy:0.9981376503506668
#
#  Recall:0.9988182462774757
#
#  Precision:0.9974581502596318
#
#  F1 Score:0.9981377349406346
#
# ==========Random Forest Classifier=============
#
#  Accuracy:0.9999364075729495
#
#  Recall:1.0
#
#  Precision:0.9998727504090166
#
#  F1 Score:0.9999363711561361

# %%
rfc = RandomForestClassifier()
rfc.fit(X_res,Y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rfc,"credit_card_model.pkl")
# Out:
# ['credit_card_model.pkl']

# %%
model = joblib.load("credit_card_model.pkl")

# %%
pred = model.predict([[-0.644269442348146, 1.41796354547385, 1.0743803763556, -0.492199018495015, 0.948934094764157, 0.428118462833089, 1.12063135838353, -3.80786423873589, 0.615374730667027, 1.24937617815176, -0.619467796121913, 0.291474353088705, 1.75796421396042, -1.32386521970526, 0.686132504394383, -0.0761269994382006, -1.2221273453247, -0.358221569869078, 0.324504731321494, -0.156741852488285, 1.94346533978412, -1.01545470979971, 0.057503529867291, -0.649709005559993, -0.415266566234811, -0.0516342969262494, -1.20692108094258, -1.08533918832377, 40.8
]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
pred[0]
# Out:
# 0

# %%
if pred == 0:
    print("It is a Non-Fraudulent transaction")
else:
    print("It is a Fraudulent transaction")
# Out:
# It is a Non-Fraudulent transaction
